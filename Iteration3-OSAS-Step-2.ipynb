# %% [markdown]
# # INFOSYS 722 - resubmission of Iteration 2

# %% [markdown]
# ## Packages used
# pandas
# matplotlib
# numpy
# sklearn

# %% [markdown]
# # STEP 2 DATA UNDERSTANDING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('loanITERATION2.csv', encoding = "ISO-8859-1", low_memory=False)

# %% [markdown]
# ## 2.2 Describe the Data

# %%
print('No. of Observations: '+str(len(df)))
print('No. of Attributes: '+str(len(df.columns)))
df.head()
# Out:
# No. of Observations: 887377
# No. of Attributes: 68
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077430    1314167       2500         2500           2500.0   60 months
# 1  1071570    1306721       5375         5375           5350.0   60 months
# 2  1064687    1298717       9000         9000           9000.0   36 months
# 3  1069759    1304871       1000         1000           1000.0   36 months
# 4  1047704    1278806       8500         8500           8500.0   36 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     15.27        59.83     C        C4     ...               NaN     NaN
# 1     12.69       121.45     B        B5     ...               NaN     NaN
# 2     13.49       305.38     C        C1     ...               NaN     NaN
# 3     16.29        35.31     D        D1     ...               NaN     NaN
# 4     11.71       281.15     B        B3     ...               NaN     NaN
#
# ...

# %%
print('No. of Observations: '+str(len(df)))
print('No. of Attributes: '+str(len(df.columns)))
# Out:
# No. of Observations: 887377
# No. of Attributes: 68

# %%
df.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.873770e+05  8.873770e+05  887377.000000  887377.000000
# mean   3.246513e+07  3.500183e+07   14755.275323   14741.888312
# std    2.282732e+07  2.411333e+07    8435.462086    8429.904151
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    9.206646e+06  1.087713e+07    8000.000000    8000.000000
# 50%    3.443327e+07  3.709528e+07   13000.000000   13000.000000
# 75%    5.490813e+07  5.847135e+07   20000.000000   20000.000000
# max    6.861706e+07  7.354484e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    887377.000000  887377.000000  887377.000000  8.873730e+05
# mean      14702.478821      13.246738     436.717465  7.502763e+04
# std        8442.110380       4.381872     244.186749  6.469836e+04
# min           0.000000       5.320000      15.670000  0.000000e+00
# ...

# %% [markdown]
# ## 2.3 Explore the Data

# %% [markdown]
# ### Loan Status

# %%
import matplotlib.pyplot as plt
vdf = df[df.loan_status != 'Does not meet the credit policy. Status:Fully Paid']
vdf = vdf[vdf.loan_status != 'Does not meet the credit policy. Status:Charged Off']
vdf.loan_status.value_counts().sort_values().plot(kind='barh')
plt.title('Frequency of Loan Status', size = 15)
plt.ylabel('Loan Status', fontsize = 13)
plt.xlabel('Frequency', fontsize = 13)
plt.show()

# %%
vdf = df[df.loan_status != 'Does not meet the credit policy. Status:Fully Paid']
vdf = vdf[vdf.loan_status != 'Does not meet the credit policy. Status:Charged Off']
labels = list(vdf.loan_status.value_counts().index)
values = list(vdf.loan_status.value_counts().values)
fig, pos = plt.subplots(figsize=(8,8))
explode = (0.1,0.1,0,0,0,0,0,0)
pos.pie(values, labels=labels, explode=explode, autopct='%1.1f%%',shadow=True, startangle=90)
pos.axis('equal')
pos.set_title('Proportion of Loan Status', size = 15)
plt.show()

# %%
vdf = df[df.loan_status != 'Does not meet the credit policy. Status:Fully Paid']
vdf = vdf[vdf.loan_status != 'Does not meet the credit policy. Status:Charged Off']
vdf = vdf.groupby('loan_status')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.loan_status.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Loan Status', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Loan Status', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 900, i + .1, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Loan Grade

# %%
labels = list(df.grade.value_counts().index)
values = list(df.grade.value_counts().values)
fig, pos = plt.subplots(figsize=(8,8))
pos.pie(values, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90,labeldistance=1.05,textprops={'fontsize': 14})
pos.axis('equal')
pos.set_title('Loan Grade', size = 15)
plt.show()

# %%
vdf = df.groupby('grade')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('grade', ascending=False)
labels = vdf.grade.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0.
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Loan Grade', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Loan Grade', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 200, i-.2, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Verification Status

# %%
labels = list(df.verification_status.value_counts().index)
values = list(df.verification_status.value_counts().values)
fig, pos = plt.subplots(figsize = (12,6))
pos.pie(values, labels=labels,autopct='%1.1f%%',shadow=True, startangle=90)
pos.axis('equal')
pos.set_title('Verification Status', size = 15)
plt.show()

# %%
vdf = df.groupby('verification_status')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.verification_status.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Verification Status ', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Verification Status', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 900, i + .1, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Purpose of Borrowing

# %%
df['purpose'].value_counts().sort_values().plot(kind='barh')
plt.xlabel('Purpose')
plt.ylabel('Frequency')
plt.title('Purpose of Borrowing')
plt.show()

# %%
vdf = df.groupby('purpose')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.purpose.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0.
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Purpose of Borrowing', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Purpose Status', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 200, i - .3, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Employment Length

# %%
labels = list(df.emp_length.value_counts().index)
values = list(df.emp_length.value_counts().values)
fig, pos = plt.subplots(figsize = (12,6))
pos.pie(values, labels=labels,autopct='%1.1f%%',shadow=True, startangle=90, labeldistance=1.05)
pos.axis('equal')
pos.set_title('Employment Length', size = 15)
plt.show()

# %%
vdf = df.groupby('emp_length')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.emp_length.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0.8
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Employment Length', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Employment Length', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 200, i - .3, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Home Ownership

# %%
labels = list(df.home_ownership.value_counts().index)
values = list(df.home_ownership.value_counts().values)
fig, pos = plt.subplots(figsize = (12,6))
pos.pie(values, labels=labels,autopct='%1.1f%%',shadow=True, startangle=90, labeldistance=1.05)
pos.axis('equal')
pos.set_title('Home Ownership', size = 15)
plt.show()

# %%
vdf = df.groupby('home_ownership')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.home_ownership.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
ind = np.arange(len(values))
width = 0
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by Home Ownership', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('Home Ownership', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 200, i, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### State

# %%
fig,pos = plt.subplots(figsize=(14,9))
df.addr_state.value_counts().sort_values().plot(kind='barh')
plt.title('Frequency of State', size = 15)
plt.ylabel('State', fontsize = 13)
plt.xlabel('Frequency', fontsize = 13)
plt.show()

# %%
fig,pos = plt.subplots(figsize=(16,8))
vdf = df.groupby('addr_state')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.addr_state.values
values = vdf.loan_amnt.values

ind = np.arange(len(values))
width = .5
pos.barh(ind, values)
pos.set_yticks(ind+width/2)
pos.set_yticklabels(labels, minor=False)
pos.set_title('Average Loan Amount by State', size = 15)
pos.set_xlabel('Average Loan Amount', fontsize = 13)
pos.set_ylabel('State', fontsize = 13)
for i, j in enumerate(values):
    pos.text(j + 200, i-.5, str(round(j)), color='blue')
plt.show()

# %% [markdown]
# ### Loan Term

# %%
labels = list(df.term.value_counts().index)
values = list(df.term.value_counts().values)
fig, pos = plt.subplots(figsize=(5,5))
explode = (0.1,0)
pos.pie(values, labels=labels, explode=explode, autopct='%1.1f%%',shadow=True, startangle=90, labeldistance=1.05)
pos.axis('equal')
pos.set_title('Proportion of Loan Term', size = 14)
plt.show()

# %%
vdf = df.groupby('term')['loan_amnt'].mean()
vdf = vdf.reset_index().sort_values('loan_amnt')
labels = vdf.term.values
values = vdf.loan_amnt.values

fig, pos = plt.subplots(figsize=(10,5)) 
pos.bar(labels, values)
pos.set_title('Average Loan Amount by Loan Term', size = 15)
pos.set_ylabel('Average Loan Amount', fontsize = 13)
pos.set_xlabel('Loan Term', fontsize = 13)
plt.show()

# %% [markdown]
# ### Numeric Attributes

# %%
# visualizing loan amount
#plt.hist(df.loan_amnt)
df.hist('loan_amnt')
plt.xlabel('(a) Loan Amount',fontsize=12)
plt.ylabel('Probability',fontsize=12)
plt.title('Histogram of Loan Amount',size=15)
plt.show()

# %%
df.hist('funded_amnt',color='yellow')
plt.xlabel('(b) Funded Amount',fontsize=12)
plt.ylabel('Probability',fontsize=12)
plt.title('Histogram of Funded Amount',size=15)
plt.show()

# %%
df.hist('int_rate', color = 'red')
plt.xlabel('(a) Interest Rate',fontsize=12)
plt.ylabel('Probability',fontsize=12)
plt.title('Histogram of Interest Rate',size=15)
plt.show()

# %%
df.hist('installment', color='orange')
plt.xlabel('(b) Installment Amount',fontsize=12)
plt.ylabel('Probability',fontsize=12)
plt.title('Histogram of Installment Amount',size=15)
plt.show()

# %% [markdown]
# ## 2.4 Verify the Data Quality

# %%
dfsize = len(df)
print('{:<30} {:^6}'.format('Attributes','No. of Missing Values'))
for i in df:
    if df[i].isnull().sum() != 0:
        missing = dfsize - df[i].isnull().sum()
        print('{:<30} {:^6}'.format(i, str(missing)))
# Out:
# Attributes                     No. of Missing Values
# emp_length                     842552
# annual_inc                     887373
# delinq_2yrs                    887348
# earliest_cr_line               887348
# inq_last_6mths                 887348
# mths_since_last_delinq         433066
# mths_since_last_record         137053
# open_acc                       887348
# pub_rec                        887348
# revol_util                     886875
# total_acc                      887348
# last_pymnt_d                   869718
# next_pymnt_d                   634407
# last_credit_pull_d             887324
# collections_12_mths_ex_med     887232
# mths_since_last_major_derog    221703
# annual_inc_joint                511
# acc_now_delinq                 887348
# tot_coll_amt                   817102
# tot_cur_bal                    817102
# open_acc_6m                    21372
# open_il_6m                     21372
# open_il_12m                    21372
# ...

# %% [markdown]
# ### Outliers

# %%
outliers ={}
print('{:<25} {:^6}'.format('Attributes','No. of Outliers'))
for i in df:
    if df[i].dtype != 'object':
        q3, q1 = np.percentile(df[i].dropna(), [75,25])
        upper = q3 + (q3 - q1) * 1.5 
        lower = q1 - (q3 - q1) * 1.5 
        a = len(df.iloc[np.where(df[i].dropna() > upper)]) + len(df.iloc[np.where(df[i].dropna() < lower)])
        if a != 0:
            print('{:<30} {:^6}'.format(i,a))
            outliers[i] = a
outliers = pd.DataFrame([outliers.keys(), outliers.values()]).T
# Out:
# Attributes                No. of Outliers
# int_rate                        6308
# installment                    23151
# annual_inc                     39719
# dti                              81
# delinq_2yrs                    170388
# inq_last_6mths                 53834
# mths_since_last_delinq          158
# open_acc                       27477
# pub_rec                        135778
# revol_bal                      48649
# revol_util                       51
# total_acc                      18232
# out_prncp                       3363
# out_prncp_inv                   3311
# total_pymnt                    46324
# total_pymnt_inv                46390
# total_rec_prncp                56944
# total_rec_int                  63836
# total_rec_late_fee             12517
# recoveries                     24677
# collection_recovery_fee        23507
# last_pymnt_amnt                156617
# collections_12_mths_ex_med     11681
# mths_since_last_major_derog     1049
# ...

# %%
outliers
# Out:
#                               0       1
# 0                      int_rate    6308
# 1                   installment   23151
# 2                    annual_inc   39719
# 3                           dti      81
# 4                   delinq_2yrs  170388
# 5                inq_last_6mths   53834
# 6        mths_since_last_delinq     158
# 7                      open_acc   27477
# 8                       pub_rec  135778
# 9                     revol_bal   48649
# 10                   revol_util      51
# 11                    total_acc   18232
# 12                    out_prncp    3363
# 13                out_prncp_inv    3311
# 14                  total_pymnt   46324
# 15              total_pymnt_inv   46390
# 16              total_rec_prncp   56944
# 17                total_rec_int   63836
# 18           total_rec_late_fee   12517
# 19                   recoveries   24677
# 20      collection_recovery_fee   23507
# 21              last_pymnt_amnt  156617
# ...
